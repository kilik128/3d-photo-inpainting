# %% [markdown]
# <a href="https://colab.research.google.com/github/kilik128/3d-photo-inpainting/blob/master/parti_pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install parti-pytorch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting parti-pytorch
#   Downloading parti_pytorch-0.0.15-py3-none-any.whl (16 kB)
# Collecting transformers
#   Downloading transformers-4.21.0-py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 8.5 MB/s
# Collecting ema-pytorch
#   Downloading ema_pytorch-0.0.9-py3-none-any.whl (4.1 kB)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from parti-pytorch) (0.13.0+cu113)
# Requirement already satisfied: torch>=1.6 in /usr/local/lib/python3.7/dist-packages (from parti-pytorch) (1.12.0+cu113)
# Collecting vector-quantize-pytorch>=0.7.3
#   Downloading vector_quantize_pytorch-0.9.1-py3-none-any.whl (7.5 kB)
# Collecting einops>=0.4
#   Downloading einops-0.4.1-py3-none-any.whl (28 kB)
# Collecting einops-exts
#   Downloading einops_exts-0.0.3-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6->parti-pytorch) (4.1.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->parti-pytorch) (7.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision->parti-pytorch) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision->parti-pytorch) (1.21.6)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->parti-pytorch) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->parti-pytorch) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->parti-pytorch) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->parti-pytorch) (2022.6.15)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers->parti-pytorch) (4.64.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers->parti-pytorch) (3.7.1)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 62.8 MB/s
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.8.1-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 15.5 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers->parti-pytorch) (4.12.0)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 89.7 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers->parti-pytorch) (2022.6.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers->parti-pytorch) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers->parti-pytorch) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers->parti-pytorch) (3.8.1)
# Installing collected packages: pyyaml, tokenizers, huggingface-hub, einops, vector-quantize-pytorch, transformers, ema-pytorch, einops-exts, parti-pytorch
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed einops-0.4.1 einops-exts-0.0.3 ema-pytorch-0.0.9 huggingface-hub-0.8.1 parti-pytorch-0.0.15 pyyaml-6.0 tokenizers-0.12.1 transformers-4.21.0 vector-quantize-pytorch-0.9.1

# %%
# %cd /content/parti-pytorch
# Out:
# /content/parti-pytorch

# %%
 # !python setup.py
# Out:
# usage: setup.py [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#    or: setup.py --help [cmd1 cmd2 ...]
#    or: setup.py --help-commands
#    or: setup.py cmd --help
#
# error: no commands supplied

# %%
from parti_pytorch import VitVQGanVAE, VQGanVAETrainer

vit_vae = VitVQGanVAE(
    dim = 256,               # dimensions
    image_size = 256,        # target image size
    patch_size = 16,         # size of the patches in the image attending to each other
    num_layers = 3           # number of layers
).cuda()

trainer = VQGanVAETrainer(
    vit_vae,
    folder = '/path/to/your/images',
    num_train_steps = 100000,
    lr = 3e-4,
    batch_size = 4,
    grad_accum_every = 8,
    amp = True
)

trainer.train()
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# 0 training samples found at /path/to/your/images
# training with dataset of 0 samples and validating with randomly splitted 0 samples
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-5656bb7714ec> in <module>()
#      15     batch_size = 4,
#      16     grad_accum_every = 8,
# ---> 17     amp = True
#      18 )
#      19
#
# /content/parti-pytorch/parti_pytorch/vit_vqgan_trainer.py in __init__(self, vae, num_train_steps, batch_size, folder, lr, grad_accum_every, wd, save_results_every, save_model_every, results_folder, valid_frac, random_split_seed, ema_beta, ema_update_after_step, ema_update_every, apply_grad_penalty_every, amp)
#     148             self.ds,
#     149             batch_size = batch_size,
# --> 150             shuffle = True
#     151         ))
#     152
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in __init__(self, dataset, batch_size, shuffle, sampler, batch_sampler, num_workers, collate_fn, pin_memory, drop_last, timeout, worker_init_fn, multiprocessing_context, generator, prefetch_factor, persistent_workers, pin_memory_device)
#     345             else:  # map-style
#     346                 if shuffle:
# --> 347                     sampler = RandomSampler(dataset, generator=generator)  # type: ignore[arg-type]
#     348                 else:
#     349                     sampler = SequentialSampler(dataset)  # type: ignore[arg-type]
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/sampler.py in __init__(self, data_source, replacement, num_samples, generator)
#     106         if not isinstance(self.num_samples, int) or self.num_samples <= 0:
#     107             raise ValueError("num_samples should be a positive integer "
# --> 108                              "value, but got num_samples={}".format(self.num_samples))
#     109
#     110     @property
#
# ValueError: num_samples should be a positive integer value, but got num_samples=0

# %%
import torch
from parti_pytorch import Parti, VitVQGanVAE

# first instantiate your ViT VQGan VAE
# a VQGan VAE made of transformers

vit_vae = VitVQGanVAE(
    dim = 256,               # dimensions
    image_size = 256,        # target image size
    patch_size = 16,         # size of the patches in the image attending to each other
    num_layers = 3           # number of layers
).cuda()

vit_vae.load_state_dict(torch.load(f'/path/to/vae.pt')) # you will want to load the exponentially moving averaged VAE

# then you plugin the ViT VqGan VAE into your Parti as so

parti = Parti(
    vae = vit_vae,            # vit vqgan vae
    dim = 512,                # model dimension
    depth = 8,                # depth
    dim_head = 64,            # attention head dimension
    heads = 8,                # attention heads
    dropout = 0.,             # dropout
    cond_drop_prob = 0.25,    # conditional dropout, for classifier free guidance
    ff_mult = 4,              # feedforward expansion factor
    t5_name = 't5-large',     # name of your T5
)

# ready your training text and images

texts = [
    'a child screaming at finding a worm within a half-eaten apple',
    'lizard running across the desert on two feet',
    'waking up to a psychedelic landscape',
    'seashells sparkling in the shallow waters'
]

images = torch.randn(4, 3, 256, 256).cuda()

# feed it into your parti instance, with return_loss set to True

loss = parti(
    texts = texts,
    images = images,
    return_loss = True
)

loss.backward()

# do this for a long time on much data
# then...

images = parti.generate(texts = [
    'a whale breaching from afar',
    'young girl blowing out candles on her birthday cake',
    'fireworks with blue and green sparkles'
], cond_scale = 3., return_pil_images = True) # conditioning scale for classifier free guidance

# List[PILImages] (256 x 256 RGB)
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-daabe813742d> in <module>()
#      12 ).cuda()
#      13
# ---> 14 vit_vae.load_state_dict(torch.load(f'/path/to/vae.pt')) # you will want to load the exponentially moving averaged VAE
#      15
#      16 # then you plugin the ViT VqGan VAE into your Parti as so
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     697         pickle_load_args['encoding'] = 'utf-8'
#     698
# --> 699     with _open_file_like(f, 'rb') as opened_file:
#     700         if _is_zipfile(opened_file):
#     701             # The zipfile reader is going to advance the current file position.
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     228 def _open_file_like(name_or_buffer, mode):
#     229     if _is_path(name_or_buffer):
# --> 230         return _open_file(name_or_buffer, mode)
#     231     else:
#     232         if 'w' in mode:
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in __init__(self, name, mode)
#     209 class _open_file(_opener):
#     210     def __init__(self, name, mode):
# --> 211         super(_open_file, self).__init__(open(name, mode))
#     212
#     213     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/path/to/vae.pt'

# %% [markdown]
# https://github.com/lucidrains/parti-pytorch

# %%
# !pip install imagen-pytorch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting imagen-pytorch
#   Downloading imagen_pytorch-1.5.10-py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 5.0 MB/s
# Requirement already satisfied: einops-exts in /usr/local/lib/python3.7/dist-packages (from imagen-pytorch) (0.0.3)
# Requirement already satisfied: einops>=0.4 in /usr/local/lib/python3.7/dist-packages (from imagen-pytorch) (0.4.1)
# Collecting accelerate
#   Downloading accelerate-0.11.0-py3-none-any.whl (123 kB)
#      |████████████████████████████████| 123 kB 12.3 MB/s
# Collecting pytorch-lightning
#   Downloading pytorch_lightning-1.6.5-py3-none-any.whl (585 kB)
#      |████████████████████████████████| 585 kB 62.5 MB/s
# Collecting kornia
#   Downloading kornia-0.6.6-py2.py3-none-any.whl (517 kB)
#      |████████████████████████████████| 517 kB 76.3 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from imagen-pytorch) (4.64.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from imagen-pytorch) (7.1.2)
# Requirement already satisfied: ema-pytorch>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from imagen-pytorch) (0.0.9)
# Collecting fsspec
#   Downloading fsspec-2022.7.1-py3-none-any.whl (141 kB)
#      |████████████████████████████████| 141 kB 88.2 MB/s
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 62.2 MB/s
# Requirement already satisfied: torch>=1.6 in /usr/local/lib/python3.7/dist-packages (from imagen-pytorch) (1.12.0+cu113)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from imagen-pytorch) (21.3)
# Collecting pytorch-warmup
#   Downloading pytorch-warmup-0.1.0.tar.gz (314 kB)
#      |████████████████████████████████| 314 kB 77.1 MB/s
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (from imagen-pytorch) (4.21.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from imagen-pytorch) (7.1.2)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.7/dist-packages (from imagen-pytorch) (1.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from imagen-pytorch) (1.21.6)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from imagen-pytorch) (0.13.0+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6->imagen-pytorch) (4.1.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from accelerate->imagen-pytorch) (6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from accelerate->imagen-pytorch) (5.4.8)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->imagen-pytorch) (3.0.9)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning->imagen-pytorch) (2.8.0)
# Collecting torchmetrics>=0.4.1
#   Downloading torchmetrics-0.9.3-py3-none-any.whl (419 kB)
#      |████████████████████████████████| 419 kB 47.9 MB/s
# Collecting pyDeprecate>=0.3.1
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Requirement already satisfied: protobuf<=3.20.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning->imagen-pytorch) (3.17.3)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from fsspec->imagen-pytorch) (3.8.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from fsspec->imagen-pytorch) (2.23.0)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf<=3.20.1->pytorch-lightning->imagen-pytorch) (1.15.0)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning->imagen-pytorch) (1.47.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning->imagen-pytorch) (0.6.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning->imagen-pytorch) (0.37.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning->imagen-pytorch) (1.35.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning->imagen-pytorch) (1.2.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning->imagen-pytorch) (57.4.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning->imagen-pytorch) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning->imagen-pytorch) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning->imagen-pytorch) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning->imagen-pytorch) (3.4.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning->imagen-pytorch) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning->imagen-pytorch) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning->imagen-pytorch) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning->imagen-pytorch) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning->imagen-pytorch) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning->imagen-pytorch) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning->imagen-pytorch) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec->imagen-pytorch) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec->imagen-pytorch) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec->imagen-pytorch) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec->imagen-pytorch) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning->imagen-pytorch) (3.2.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec->imagen-pytorch) (2.1.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec->imagen-pytorch) (22.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec->imagen-pytorch) (1.2.0)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec->imagen-pytorch) (0.13.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec->imagen-pytorch) (1.3.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec->imagen-pytorch) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec->imagen-pytorch) (1.7.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec->imagen-pytorch) (6.0.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers->imagen-pytorch) (0.8.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers->imagen-pytorch) (3.7.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers->imagen-pytorch) (2022.6.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers->imagen-pytorch) (0.12.1)
# Building wheels for collected packages: pytorch-warmup
#   Building wheel for pytorch-warmup (setup.py) ... done
#   Created wheel for pytorch-warmup: filename=pytorch_warmup-0.1.0-py3-none-any.whl size=5802 sha256=266799858b8f72a3f1bfbfe5a94f95b808cad7cef0387193517a0dcf7570505f
#   Stored in directory: /root/.cache/pip/wheels/c7/5d/24/9475e442daa1e9332c122c79fb5131b9e4e91946009365902e
# Successfully built pytorch-warmup
# Installing collected packages: fsspec, torchmetrics, pyDeprecate, sentencepiece, pytorch-warmup, pytorch-lightning, kornia, accelerate, imagen-pytorch
# Successfully installed accelerate-0.11.0 fsspec-2022.7.1 imagen-pytorch-1.5.10 kornia-0.6.6 pyDeprecate-0.3.2 pytorch-lightning-1.6.5 pytorch-warmup-0.1.0 sentencepiece-0.1.96 torchmetrics-0.9.3

# %%
import torch
from imagen_pytorch import Unet, Imagen

# unet for imagen

unet1 = Unet(
    dim = 32,
    cond_dim = 512,
    dim_mults = (1, 2, 4, 8),
    num_resnet_blocks = 3,
    layer_attns = (False, True, True, True),
    layer_cross_attns = (False, True, True, True)
)

unet2 = Unet(
    dim = 32,
    cond_dim = 512,
    dim_mults = (1, 2, 4, 8),
    num_resnet_blocks = (2, 4, 8, 8),
    layer_attns = (False, False, False, True),
    layer_cross_attns = (False, False, False, True)
)

# imagen, which contains the unets above (base unet and super resoluting ones)

imagen = Imagen(
    unets = (unet1, unet2),
    image_sizes = (64, 256),
    timesteps = 1000,
    cond_drop_prob = 0.1
).cuda()

# mock images (get a lot of this) and text encodings from large T5

text_embeds = torch.randn(4, 256, 768).cuda()
images = torch.randn(4, 3, 256, 256).cuda()

# feed images into imagen, training each unet in the cascade

for i in (1, 2):
    loss = imagen(images, text_embeds = text_embeds, unet_number = i)
    loss.backward()

# do the above for many many many many steps
# now you can sample an image based on the text embeddings from the cascading ddpm

images = imagen.sample(texts = [
    'a whale breaching from afar',
    'young girl blowing out candles on her birthday cake',
    'fireworks with blue and green sparkles'
], cond_scale = 3.)

images.shape # (3, 3, 256, 256)
# Out:
# Downloading config.json:   0%|          | 0.00/605 [00:00<?, ?B/s]
# The base dimension of your u-net should ideally be no smaller than 128, as recommended by a professional DDPM trainer https://nonint.com/2022/05/04/friends-dont-let-friends-train-small-diffusion-models/
# Downloading pytorch_model.bin:   0%|          | 0.00/945M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-1fbe25461db8> in <module>()
#      49     'young girl blowing out candles on her birthday cake',
#      50     'fireworks with blue and green sparkles'
# ---> 51 ], cond_scale = 3.)
#      52
#      53 images.shape # (3, 3, 256, 256)
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.clone():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# /usr/local/lib/python3.7/dist-packages/imagen_pytorch/imagen_pytorch.py in inner(model, *args, **kwargs)
#      91         was_training = model.training
#      92         model.eval()
# ---> 93         out = fn(model, *args, **kwargs)
#      94         model.train(was_training)
#      95         return out
#
# /usr/local/lib/python3.7/dist-packages/imagen_pytorch/imagen_pytorch.py in sample(self, texts, text_masks, text_embeds, cond_images, inpaint_images, inpaint_masks, inpaint_resample_times, batch_size, cond_scale, lowres_sample_noise_level, stop_at_unet_number, return_all_unet_outputs, return_pil_images, device, use_tqdm)
#    2089         if exists(texts) and not exists(text_embeds) and not self.unconditional:
#    2090             with autocast(enabled = False):
# -> 2091                 text_embeds, text_masks = self.encode_text(texts, return_attn_mask = True)
#    2092
#    2093             text_embeds, text_masks = map(lambda t: t.to(device), (text_embeds, text_masks))
#
# /usr/local/lib/python3.7/dist-packages/imagen_pytorch/t5.py in t5_encode_text(texts, name, return_attn_mask)
#     110     return_attn_mask = False
#     111 ):
# --> 112     token_ids, attn_mask = t5_tokenize(texts, name = name)
#     113     encoded_text = t5_encode_tokenized_text(token_ids, attn_mask = attn_mask, name = name)
#     114
#
# /usr/local/lib/python3.7/dist-packages/imagen_pytorch/t5.py in t5_tokenize(texts, name)
#      64     name = DEFAULT_T5_NAME
#      65 ):
# ---> 66     t5, tokenizer = get_model_and_tokenizer(name)
#      67
#      68     if torch.cuda.is_available():
#
# /usr/local/lib/python3.7/dist-packages/imagen_pytorch/t5.py in get_model_and_tokenizer(name)
#      41         T5_CONFIGS[name]["model"] = get_model(name)
#      42     if "tokenizer" not in T5_CONFIGS[name]:
# ---> 43         T5_CONFIGS[name]["tokenizer"] = get_tokenizer(name)
#      44
#      45     return T5_CONFIGS[name]['model'], T5_CONFIGS[name]['tokenizer']
#
# /usr/local/lib/python3.7/dist-packages/imagen_pytorch/t5.py in get_tokenizer(name)
#      26
#      27 def get_tokenizer(name):
# ---> 28     tokenizer = T5Tokenizer.from_pretrained(name)
#      29     return tokenizer
#      30
#
# TypeError: 'NoneType' object is not callable

# %%
import torch
from imagen_pytorch import Unet, Imagen, SRUnet256, ImagenTrainer
from IPython.display import Image
# unets for unconditional imagen

unet1 = Unet(
    dim = 32,
    dim_mults = (1, 2, 4),
    num_resnet_blocks = 3,
    layer_attns = (False, True, True),
    layer_cross_attns = False,
    use_linear_attn = True
)

unet2 = SRUnet256(
    dim = 32,
    dim_mults = (1, 2, 4),
    num_resnet_blocks = (2, 4, 8),
    layer_attns = (False, False, True),
    layer_cross_attns = False
)

# imagen, which contains the unets above (base unet and super resoluting ones)

imagen = Imagen(
    condition_on_text = False,   # this must be set to False for unconditional Imagen
    unets = (unet1, unet2),
    image_sizes = (64, 128),
    timesteps = 1000
)

trainer = ImagenTrainer(imagen).cuda()

# now get a ton of images and feed it through the Imagen trainer

training_images = torch.randn(4, 3, 256, 256).cuda()

# train each unet separately
# in this example, only training on unet number 1

loss = trainer(training_images, unet_number = 1)
trainer.update(unet_number = 1)

# do the above for many many many many steps
# now you can sample images unconditionally from the cascading unet(s)

images = trainer.sample(batch_size = 16) # (16, 3, 128, 128)

Image(images)
# Out:
# unet 2 has not been trained
# when sampling, you can pass stop_at_unet_number to stop early in the cascade, so it does not try to generate with untrained unets
# 0it [00:00, ?it/s]
# sampling loop time step:   0%|          | 0/1000 [00:00<?, ?it/s]
# sampling loop time step:   0%|          | 2/1000 [00:00<01:22, 12.16it/s]
# sampling loop time step:   0%|          | 4/1000 [00:00<01:40,  9.95it/s]
# sampling loop time step:   1%|          | 6/1000 [00:00<01:45,  9.42it/s]
# sampling loop time step:   1%|          | 7/1000 [00:00<01:46,  9.29it/s]
# sampling loop time step:   1%|          | 8/1000 [00:00<01:47,  9.19it/s]
# sampling loop time step:   1%|          | 9/1000 [00:00<01:48,  9.10it/s]
# sampling loop time step:   1%|          | 10/1000 [00:01<01:49,  9.04it/s]
# sampling loop time step:   1%|          | 11/1000 [00:01<01:49,  9.00it/s]
# sampling loop time step:   1%|          | 12/1000 [00:01<01:50,  8.96it/s]
# sampling loop time step:   1%|▏         | 13/1000 [00:01<01:50,  8.93it/s]
# sampling loop time step:   1%|▏         | 14/1000 [00:01<01:50,  8.92it/s]
# sampling loop time step:   2%|▏         | 15/1000 [00:01<01:50,  8.91it/s]
# sampling loop time step:   2%|▏         | 16/1000 [00:01<01:50,  8.90it/s]
# sampling loop time step:   2%|▏         | 17/1000 [00:01<01:50,  8.90it/s]
# sampling loop time step:   2%|▏         | 18/1000 [00:01<01:50,  8.89it/s]
# sampling loop time step:   2%|▏         | 19/1000 [00:02<01:50,  8.90it/s]
# sampling loop time step:   2%|▏         | 20/1000 [00:02<01:50,  8.90it/s]
# sampling loop time step:   2%|▏         | 21/1000 [00:02<01:50,  8.90it/s]
# sampling loop time step:   2%|▏         | 22/1000 [00:02<01:50,  8.89it/s]
# sampling loop time step:   2%|▏         | 23/1000 [00:02<01:49,  8.90it/s]
# sampling loop time step:   2%|▏         | 24/1000 [00:02<01:49,  8.89it/s]
# sampling loop time step:   2%|▎         | 25/1000 [00:02<01:49,  8.89it/s]
# sampling loop time step:   3%|▎         | 26/1000 [00:02<01:49,  8.88it/s]
# sampling loop time step:   3%|▎         | 27/1000 [00:02<01:49,  8.89it/s]
# sampling loop time step:   3%|▎         | 28/1000 [00:03<01:49,  8.89it/s]
# sampling loop time step:   3%|▎         | 29/1000 [00:03<01:49,  8.89it/s]
# sampling loop time step:   3%|▎         | 30/1000 [00:03<01:49,  8.88it/s]
# sampling loop time step:   3%|▎         | 31/1000 [00:03<01:49,  8.89it/s]
# sampling loop time step:   3%|▎         | 32/1000 [00:03<01:48,  8.89it/s]
# sampling loop time step:   3%|▎         | 33/1000 [00:03<01:48,  8.89it/s]
# sampling loop time step:   3%|▎         | 34/1000 [00:03<01:48,  8.89it/s]
# sampling loop time step:   4%|▎         | 35/1000 [00:03<01:48,  8.90it/s]
# sampling loop time step:   4%|▎         | 36/1000 [00:03<01:48,  8.90it/s]
# sampling loop time step:   4%|▎         | 37/1000 [00:04<01:48,  8.90it/s]
# sampling loop time step:   4%|▍         | 38/1000 [00:04<01:48,  8.89it/s]
# sampling loop time step:   4%|▍         | 39/1000 [00:04<01:48,  8.90it/s]
# sampling loop time step:   4%|▍         | 40/1000 [00:04<01:47,  8.89it/s]
# sampling loop time step:   4%|▍         | 41/1000 [00:04<01:47,  8.89it/s]
# sampling loop time step:   4%|▍         | 42/1000 [00:04<01:47,  8.88it/s]
# sampling loop time step:   4%|▍         | 43/1000 [00:04<01:47,  8.88it/s]
# sampling loop time step:   4%|▍         | 44/1000 [00:04<01:47,  8.89it/s]
# sampling loop time step:   4%|▍         | 45/1000 [00:05<01:47,  8.88it/s]
# sampling loop time step:   5%|▍         | 46/1000 [00:05<01:47,  8.89it/s]
# sampling loop time step:   5%|▍         | 47/1000 [00:05<01:47,  8.90it/s]
# sampling loop time step:   5%|▍         | 48/1000 [00:05<01:47,  8.88it/s]
# sampling loop time step:   5%|▍         | 49/1000 [00:05<01:47,  8.89it/s]
# sampling loop time step:   5%|▌         | 50/1000 [00:05<01:46,  8.89it/s]
# sampling loop time step:   5%|▌         | 51/1000 [00:05<01:46,  8.89it/s]
# sampling loop time step:   5%|▌         | 52/1000 [00:05<01:46,  8.89it/s]
# sampling loop time step:   5%|▌         | 53/1000 [00:05<01:46,  8.89it/s]
# sampling loop time step:   5%|▌         | 54/1000 [00:06<01:46,  8.89it/s]
# sampling loop time step:   6%|▌         | 55/1000 [00:06<01:46,  8.89it/s]
# sampling loop time step:   6%|▌         | 56/1000 [00:06<01:46,  8.89it/s]
# sampling loop time step:   6%|▌         | 57/1000 [00:06<01:46,  8.88it/s]
# sampling loop time step:   6%|▌         | 58/1000 [00:06<01:45,  8.90it/s]
# sampling loop time step:   6%|▌         | 59/1000 [00:06<01:45,  8.90it/s]
# sampling loop time step:   6%|▌         | 60/1000 [00:06<01:45,  8.90it/s]
# sampling loop time step:   6%|▌         | 61/1000 [00:06<01:45,  8.90it/s]
# sampling loop time step:   6%|▌         | 62/1000 [00:06<01:45,  8.89it/s]
# sampling loop time step:   6%|▋         | 63/1000 [00:07<01:45,  8.88it/s]
# sampling loop time step:   6%|▋         | 64/1000 [00:07<01:45,  8.89it/s]
# sampling loop time step:   6%|▋         | 65/1000 [00:07<01:45,  8.90it/s]
# sampling loop time step:   7%|▋         | 66/1000 [00:07<01:45,  8.88it/s]
# sampling loop time step:   7%|▋         | 67/1000 [00:07<01:44,  8.89it/s]
# sampling loop time step:   7%|▋         | 68/1000 [00:07<01:44,  8.89it/s]
# sampling loop time step:   7%|▋         | 69/1000 [00:07<01:44,  8.89it/s]
# sampling loop time step:   7%|▋         | 70/1000 [00:07<01:44,  8.90it/s]
# sampling loop time step:   7%|▋         | 71/1000 [00:07<01:44,  8.90it/s]
# sampling loop time step:   7%|▋         | 72/1000 [00:08<01:44,  8.89it/s]
# sampling loop time step:   7%|▋         | 73/1000 [00:08<01:44,  8.89it/s]
# sampling loop time step:   7%|▋         | 74/1000 [00:08<01:44,  8.89it/s]
# sampling loop time step:   8%|▊         | 75/1000 [00:08<01:44,  8.88it/s]
# sampling loop time step:   8%|▊         | 76/1000 [00:08<01:43,  8.89it/s]
# sampling loop time step:   8%|▊         | 77/1000 [00:08<01:43,  8.90it/s]
# sampling loop time step:   8%|▊         | 78/1000 [00:08<01:43,  8.89it/s]
# sampling loop time step:   8%|▊         | 79/1000 [00:08<01:43,  8.89it/s]
# sampling loop time step:   8%|▊         | 80/1000 [00:08<01:43,  8.89it/s]
# sampling loop time step:   8%|▊         | 81/1000 [00:09<01:43,  8.87it/s]
# sampling loop time step:   8%|▊         | 82/1000 [00:09<01:43,  8.89it/s]
# sampling loop time step:   8%|▊         | 83/1000 [00:09<01:43,  8.85it/s]
# sampling loop time step:   8%|▊         | 84/1000 [00:09<01:43,  8.89it/s]
# sampling loop time step:   8%|▊         | 85/1000 [00:09<01:42,  8.90it/s]
# sampling loop time step:   9%|▊         | 86/1000 [00:09<01:42,  8.90it/s]
# sampling loop time step:   9%|▊         | 87/1000 [00:09<01:42,  8.88it/s]
# sampling loop time step:   9%|▉         | 88/1000 [00:09<01:42,  8.89it/s]
# sampling loop time step:   9%|▉         | 89/1000 [00:09<01:42,  8.90it/s]
# sampling loop time step:   9%|▉         | 90/1000 [00:10<01:42,  8.88it/s]
# sampling loop time step:   9%|▉         | 91/1000 [00:10<01:42,  8.89it/s]
# sampling loop time step:   9%|▉         | 92/1000 [00:10<01:41,  8.90it/s]
# sampling loop time step:   9%|▉         | 93/1000 [00:10<01:42,  8.89it/s]
# sampling loop time step:   9%|▉         | 94/1000 [00:10<01:41,  8.89it/s]
# sampling loop time step:  10%|▉         | 95/1000 [00:10<01:41,  8.88it/s]
# sampling loop time step:  10%|▉         | 96/1000 [00:10<01:41,  8.87it/s]
# sampling loop time step:  10%|▉         | 97/1000 [00:10<01:41,  8.88it/s]
# sampling loop time step:  10%|▉         | 98/1000 [00:10<01:41,  8.88it/s]
# sampling loop time step:  10%|▉         | 99/1000 [00:11<01:41,  8.86it/s]
# sampling loop time step:  10%|█         | 100/1000 [00:11<01:41,  8.87it/s]
# sampling loop time step:  10%|█         | 101/1000 [00:11<01:41,  8.88it/s]
# sampling loop time step:  10%|█         | 102/1000 [00:11<01:41,  8.87it/s]
# sampling loop time step:  10%|█         | 103/1000 [00:11<01:41,  8.87it/s]
# sampling loop time step:  10%|█         | 104/1000 [00:11<01:40,  8.87it/s]
# sampling loop time step:  10%|█         | 105/1000 [00:11<01:40,  8.87it/s]
# sampling loop time step:  11%|█         | 106/1000 [00:11<01:40,  8.88it/s]
# sampling loop time step:  11%|█         | 107/1000 [00:11<01:40,  8.89it/s]
# sampling loop time step:  11%|█         | 108/1000 [00:12<01:40,  8.86it/s]
# sampling loop time step:  11%|█         | 109/1000 [00:12<01:40,  8.87it/s]
# sampling loop time step:  11%|█         | 110/1000 [00:12<01:40,  8.87it/s]
# sampling loop time step:  11%|█         | 111/1000 [00:12<01:40,  8.87it/s]
# sampling loop time step:  11%|█         | 112/1000 [00:12<01:40,  8.88it/s]
# sampling loop time step:  11%|█▏        | 113/1000 [00:12<01:39,  8.88it/s]
# sampling loop time step:  11%|█▏        | 114/1000 [00:12<01:39,  8.87it/s]
# sampling loop time step:  12%|█▏        | 115/1000 [00:12<01:39,  8.87it/s]
# sampling loop time step:  12%|█▏        | 116/1000 [00:12<01:39,  8.88it/s]
# sampling loop time step:  12%|█▏        | 117/1000 [00:13<01:39,  8.88it/s]
# sampling loop time step:  12%|█▏        | 118/1000 [00:13<01:39,  8.88it/s]
# sampling loop time step:  12%|█▏        | 119/1000 [00:13<01:39,  8.88it/s]
# sampling loop time step:  12%|█▏        | 120/1000 [00:13<01:39,  8.86it/s]
# sampling loop time step:  12%|█▏        | 121/1000 [00:13<01:39,  8.87it/s]
# sampling loop time step:  12%|█▏        | 122/1000 [00:13<01:38,  8.88it/s]
# sampling loop time step:  12%|█▏        | 123/1000 [00:13<01:38,  8.88it/s]
# sampling loop time step:  12%|█▏        | 124/1000 [00:13<01:38,  8.89it/s]
# sampling loop time step:  12%|█▎        | 125/1000 [00:14<01:38,  8.89it/s]
# sampling loop time step:  13%|█▎        | 126/1000 [00:14<01:38,  8.88it/s]
# sampling loop time step:  13%|█▎        | 127/1000 [00:14<01:38,  8.89it/s]
# sampling loop time step:  13%|█▎        | 128/1000 [00:14<01:38,  8.89it/s]
# sampling loop time step:  13%|█▎        | 129/1000 [00:14<01:38,  8.87it/s]
# sampling loop time step:  13%|█▎        | 130/1000 [00:14<01:38,  8.87it/s]
# sampling loop time step:  13%|█▎        | 131/1000 [00:14<01:37,  8.88it/s]
# sampling loop time step:  13%|█▎        | 132/1000 [00:14<01:37,  8.87it/s]
# sampling loop time step:  13%|█▎        | 133/1000 [00:14<01:37,  8.88it/s]
# sampling loop time step:  13%|█▎        | 134/1000 [00:15<01:37,  8.88it/s]
# sampling loop time step:  14%|█▎        | 135/1000 [00:15<01:37,  8.87it/s]
# sampling loop time step:  14%|█▎        | 136/1000 [00:15<01:37,  8.88it/s]
# sampling loop time step:  14%|█▎        | 137/1000 [00:15<01:37,  8.89it/s]
# sampling loop time step:  14%|█▍        | 138/1000 [00:15<01:37,  8.87it/s]
# sampling loop time step:  14%|█▍        | 139/1000 [00:15<01:37,  8.87it/s]
# sampling loop time step:  14%|█▍        | 140/1000 [00:15<01:36,  8.88it/s]
# sampling loop time step:  14%|█▍        | 141/1000 [00:15<01:36,  8.88it/s]
# sampling loop time step:  14%|█▍        | 142/1000 [00:15<01:36,  8.88it/s]
# sampling loop time step:  14%|█▍        | 143/1000 [00:16<01:36,  8.88it/s]
# sampling loop time step:  14%|█▍        | 144/1000 [00:16<01:36,  8.87it/s]
# sampling loop time step:  14%|█▍        | 145/1000 [00:16<01:36,  8.88it/s]
# sampling loop time step:  15%|█▍        | 146/1000 [00:16<01:36,  8.89it/s]
# sampling loop time step:  15%|█▍        | 147/1000 [00:16<01:36,  8.88it/s]
# sampling loop time step:  15%|█▍        | 148/1000 [00:16<01:35,  8.88it/s]
# sampling loop time step:  15%|█▍        | 149/1000 [00:16<01:35,  8.87it/s]
# sampling loop time step:  15%|█▌        | 150/1000 [00:16<01:35,  8.87it/s]
# sampling loop time step:  15%|█▌        | 151/1000 [00:16<01:35,  8.89it/s]
# sampling loop time step:  15%|█▌        | 152/1000 [00:17<01:35,  8.89it/s]
# sampling loop time step:  15%|█▌        | 153/1000 [00:17<01:35,  8.88it/s]
# sampling loop time step:  15%|█▌        | 154/1000 [00:17<01:35,  8.89it/s]
# sampling loop time step:  16%|█▌        | 155/1000 [00:17<01:35,  8.88it/s]
# sampling loop time step:  16%|█▌        | 156/1000 [00:17<01:35,  8.88it/s]
# sampling loop time step:  16%|█▌        | 157/1000 [00:17<01:35,  8.87it/s]
# sampling loop time step:  16%|█▌        | 158/1000 [00:17<01:34,  8.88it/s]
# sampling loop time step:  16%|█▌        | 159/1000 [00:17<01:34,  8.88it/s]
# sampling loop time step:  16%|█▌        | 160/1000 [00:17<01:34,  8.89it/s]
# sampling loop time step:  16%|█▌        | 161/1000 [00:18<01:34,  8.89it/s]
# sampling loop time step:  16%|█▌        | 162/1000 [00:18<01:34,  8.88it/s]
# sampling loop time step:  16%|█▋        | 163/1000 [00:18<01:34,  8.88it/s]
# sampling loop time step:  16%|█▋        | 164/1000 [00:18<01:34,  8.88it/s]
# sampling loop time step:  16%|█▋        | 165/1000 [00:18<01:34,  8.87it/s]
# sampling loop time step:  17%|█▋        | 166/1000 [00:18<01:33,  8.87it/s]
# sampling loop time step:  17%|█▋        | 167/1000 [00:18<01:33,  8.87it/s]
# sampling loop time step:  17%|█▋        | 168/1000 [00:18<01:33,  8.87it/s]
# sampling loop time step:  17%|█▋        | 169/1000 [00:18<01:33,  8.89it/s]
# sampling loop time step:  17%|█▋        | 170/1000 [00:19<01:33,  8.89it/s]
# sampling loop time step:  17%|█▋        | 171/1000 [00:19<01:33,  8.88it/s]
# sampling loop time step:  17%|█▋        | 172/1000 [00:19<01:33,  8.89it/s]
# sampling loop time step:  17%|█▋        | 173/1000 [00:19<01:33,  8.88it/s]
# sampling loop time step:  17%|█▋        | 174/1000 [00:19<01:33,  8.87it/s]
# sampling loop time step:  18%|█▊        | 175/1000 [00:19<01:32,  8.88it/s]
# sampling loop time step:  18%|█▊        | 176/1000 [00:19<01:32,  8.87it/s]
# sampling loop time step:  18%|█▊        | 177/1000 [00:19<01:32,  8.88it/s]
# sampling loop time step:  18%|█▊        | 178/1000 [00:19<01:32,  8.88it/s]
# sampling loop time step:  18%|█▊        | 179/1000 [00:20<01:32,  8.87it/s]
# sampling loop time step:  18%|█▊        | 180/1000 [00:20<01:32,  8.88it/s]
# sampling loop time step:  18%|█▊        | 181/1000 [00:20<01:32,  8.90it/s]
# sampling loop time step:  18%|█▊        | 182/1000 [00:20<01:32,  8.89it/s]
# sampling loop time step:  18%|█▊        | 183/1000 [00:20<01:31,  8.88it/s]
# sampling loop time step:  18%|█▊        | 184/1000 [00:20<01:31,  8.89it/s]
# sampling loop time step:  18%|█▊        | 185/1000 [00:20<01:31,  8.89it/s]
# sampling loop time step:  19%|█▊        | 186/1000 [00:20<01:31,  8.89it/s]
# sampling loop time step:  19%|█▊        | 187/1000 [00:20<01:31,  8.89it/s]
# sampling loop time step:  19%|█▉        | 188/1000 [00:21<01:31,  8.88it/s]
# sampling loop time step:  19%|█▉        | 189/1000 [00:21<01:31,  8.87it/s]
# sampling loop time step:  19%|█▉        | 190/1000 [00:21<01:31,  8.89it/s]
# sampling loop time step:  19%|█▉        | 191/1000 [00:21<01:30,  8.90it/s]
# sampling loop time step:  19%|█▉        | 192/1000 [00:21<01:30,  8.89it/s]
# sampling loop time step:  19%|█▉        | 193/1000 [00:21<01:30,  8.89it/s]
# sampling loop time step:  19%|█▉        | 194/1000 [00:21<01:30,  8.89it/s]
# sampling loop time step:  20%|█▉        | 195/1000 [00:21<01:30,  8.89it/s]
# sampling loop time step:  20%|█▉        | 196/1000 [00:22<01:30,  8.89it/s]
# sampling loop time step:  20%|█▉        | 197/1000 [00:22<01:30,  8.88it/s]
# sampling loop time step:  20%|█▉        | 198/1000 [00:22<01:30,  8.87it/s]
# sampling loop time step:  20%|█▉        | 199/1000 [00:22<01:30,  8.87it/s]
# sampling loop time step:  20%|██        | 200/1000 [00:22<01:30,  8.88it/s]
# sampling loop time step:  20%|██        | 201/1000 [00:22<01:29,  8.88it/s]
# sampling loop time step:  20%|██        | 202/1000 [00:22<01:29,  8.88it/s]
# sampling loop time step:  20%|██        | 203/1000 [00:22<01:29,  8.89it/s]
# sampling loop time step:  20%|██        | 204/1000 [00:22<01:29,  8.89it/s]
# sampling loop time step:  20%|██        | 205/1000 [00:23<01:29,  8.89it/s]
# sampling loop time step:  21%|██        | 206/1000 [00:23<01:29,  8.89it/s]
# sampling loop time step:  21%|██        | 207/1000 [00:23<01:29,  8.88it/s]
# sampling loop time step:  21%|██        | 208/1000 [00:23<01:29,  8.88it/s]
# sampling loop time step:  21%|██        | 209/1000 [00:23<01:29,  8.88it/s]
# sampling loop time step:  21%|██        | 210/1000 [00:23<01:29,  8.87it/s]
# sampling loop time step:  21%|██        | 211/1000 [00:23<01:28,  8.88it/s]
# sampling loop time step:  21%|██        | 212/1000 [00:23<01:28,  8.89it/s]
# sampling loop time step:  21%|██▏       | 213/1000 [00:23<01:28,  8.88it/s]
# sampling loop time step:  21%|██▏       | 214/1000 [00:24<01:28,  8.89it/s]
# sampling loop time step:  22%|██▏       | 215/1000 [00:24<01:28,  8.89it/s]
# sampling loop time step:  22%|██▏       | 216/1000 [00:24<01:28,  8.88it/s]
# sampling loop time step:  22%|██▏       | 217/1000 [00:24<01:28,  8.90it/s]
# sampling loop time step:  22%|██▏       | 218/1000 [00:24<01:27,  8.89it/s]
# sampling loop time step:  22%|██▏       | 219/1000 [00:24<01:27,  8.89it/s]
# sampling loop time step:  22%|██▏       | 220/1000 [00:24<01:27,  8.91it/s]
# sampling loop time step:  22%|██▏       | 221/1000 [00:24<01:27,  8.89it/s]
# sampling loop time step:  22%|██▏       | 222/1000 [00:24<01:27,  8.90it/s]
# sampling loop time step:  22%|██▏       | 223/1000 [00:25<01:27,  8.90it/s]
# sampling loop time step:  22%|██▏       | 224/1000 [00:25<01:27,  8.89it/s]
# sampling loop time step:  22%|██▎       | 225/1000 [00:25<01:27,  8.89it/s]
# sampling loop time step:  23%|██▎       | 226/1000 [00:25<01:26,  8.90it/s]
# sampling loop time step:  23%|██▎       | 227/1000 [00:25<01:26,  8.90it/s]
# sampling loop time step:  23%|██▎       | 228/1000 [00:25<01:26,  8.89it/s]
# sampling loop time step:  27%|██▋       | 266/1000 [00:29<01:22,  8.88it/s]
# sampling loop time step:  27%|██▋       | 267/1000 [00:29<01:22,  8.88it/s]
# sampling loop time step:  27%|██▋       | 268/1000 [00:30<01:22,  8.89it/s]
# sampling loop time step:  27%|██▋       | 269/1000 [00:30<01:22,  8.89it/s]
# sampling loop time step:  27%|██▋       | 270/1000 [00:30<01:22,  8.90it/s]
# sampling loop time step:  27%|██▋       | 271/1000 [00:30<01:21,  8.91it/s]
# sampling loop time step:  27%|██▋       | 272/1000 [00:30<01:21,  8.90it/s]
# sampling loop time step:  27%|██▋       | 273/1000 [00:30<01:21,  8.89it/s]
# sampling loop time step:  27%|██▋       | 274/1000 [00:30<01:21,  8.90it/s]
# sampling loop time step:  28%|██▊       | 275/1000 [00:30<01:21,  8.88it/s]
# sampling loop time step:  28%|██▊       | 276/1000 [00:31<01:21,  8.89it/s]
# sampling loop time step:  28%|██▊       | 277/1000 [00:31<01:21,  8.89it/s]
# sampling loop time step:  28%|██▊       | 278/1000 [00:31<01:21,  8.89it/s]
# sampling loop time step:  28%|██▊       | 279/1000 [00:31<01:21,  8.89it/s]
# sampling loop time step:  28%|██▊       | 280/1000 [00:31<01:20,  8.90it/s]
# sampling loop time step:  28%|██▊       | 281/1000 [00:31<01:20,  8.90it/s]
# sampling loop time step:  28%|██▊       | 282/1000 [00:31<01:20,  8.91it/s]
# sampling loop time step:  28%|██▊       | 283/1000 [00:31<01:20,  8.91it/s]
# sampling loop time step:  28%|██▊       | 284/1000 [00:31<01:20,  8.90it/s]
# sampling loop time step:  28%|██▊       | 285/1000 [00:32<01:20,  8.89it/s]
# sampling loop time step:  29%|██▊       | 286/1000 [00:32<01:20,  8.90it/s]
# sampling loop time step:  29%|██▊       | 287/1000 [00:32<01:20,  8.88it/s]
# sampling loop time step:  29%|██▉       | 288/1000 [00:32<01:20,  8.89it/s]
# sampling loop time step:  29%|██▉       | 289/1000 [00:32<01:20,  8.88it/s]
# sampling loop time step:  29%|██▉       | 290/1000 [00:32<01:20,  8.87it/s]
# sampling loop time step:  29%|██▉       | 291/1000 [00:32<01:19,  8.88it/s]
# sampling loop time step:  29%|██▉       | 292/1000 [00:32<01:19,  8.89it/s]
# sampling loop time step:  29%|██▉       | 293/1000 [00:32<01:19,  8.89it/s]
# sampling loop time step:  29%|██▉       | 294/1000 [00:33<01:19,  8.89it/s]
# sampling loop time step:  30%|██▉       | 295/1000 [00:33<01:19,  8.91it/s]
# sampling loop time step:  30%|██▉       | 296/1000 [00:33<01:19,  8.89it/s]
# sampling loop time step:  30%|██▉       | 297/1000 [00:33<01:19,  8.90it/s]
# sampling loop time step:  30%|██▉       | 298/1000 [00:33<01:18,  8.89it/s]
# sampling loop time step:  30%|██▉       | 299/1000 [00:33<01:18,  8.88it/s]
# sampling loop time step:  30%|███       | 300/1000 [00:33<01:18,  8.89it/s]
# sampling loop time step:  30%|███       | 301/1000 [00:33<01:18,  8.89it/s]
# sampling loop time step:  30%|███       | 302/1000 [00:33<01:18,  8.89it/s]
# sampling loop time step:  30%|███       | 303/1000 [00:34<01:18,  8.90it/s]
# sampling loop time step:  30%|███       | 304/1000 [00:34<01:18,  8.90it/s]
# sampling loop time step:  30%|███       | 305/1000 [00:34<01:18,  8.90it/s]
# sampling loop time step:  31%|███       | 306/1000 [00:34<01:17,  8.90it/s]
# sampling loop time step:  31%|███       | 307/1000 [00:34<01:17,  8.91it/s]
# sampling loop time step:  31%|███       | 308/1000 [00:34<01:17,  8.91it/s]
# sampling loop time step:  31%|███       | 309/1000 [00:34<01:17,  8.90it/s]
# sampling loop time step:  31%|███       | 310/1000 [00:34<01:17,  8.89it/s]
# sampling loop time step:  31%|███       | 311/1000 [00:34<01:17,  8.88it/s]
# sampling loop time step:  31%|███       | 312/1000 [00:35<01:17,  8.89it/s]
# sampling loop time step:  31%|███▏      | 313/1000 [00:35<01:17,  8.90it/s]
# sampling loop time step:  31%|███▏      | 314/1000 [00:35<01:17,  8.89it/s]
# sampling loop time step:  32%|███▏      | 315/1000 [00:35<01:17,  8.89it/s]
# sampling loop time step:  32%|███▏      | 316/1000 [00:35<01:16,  8.89it/s]
# sampling loop time step:  32%|███▏      | 317/1000 [00:35<01:16,  8.89it/s]
# sampling loop time step:  32%|███▏      | 318/1000 [00:35<01:16,  8.89it/s]
# sampling loop time step:  32%|███▏      | 319/1000 [00:35<01:16,  8.90it/s]
# sampling loop time step:  32%|███▏      | 320/1000 [00:35<01:16,  8.89it/s]
# sampling loop time step:  32%|███▏      | 321/1000 [00:36<01:16,  8.90it/s]
# sampling loop time step:  32%|███▏      | 322/1000 [00:36<01:16,  8.89it/s]
# sampling loop time step:  32%|███▏      | 323/1000 [00:36<01:16,  8.87it/s]
# sampling loop time step:  32%|███▏      | 324/1000 [00:36<01:16,  8.88it/s]
# sampling loop time step:  32%|███▎      | 325/1000 [00:36<01:15,  8.89it/s]
# sampling loop time step:  33%|███▎      | 326/1000 [00:36<01:15,  8.89it/s]
# sampling loop time step:  33%|███▎      | 327/1000 [00:36<01:15,  8.88it/s]
# sampling loop time step:  33%|███▎      | 328/1000 [00:36<01:15,  8.89it/s]
# sampling loop time step:  33%|███▎      | 329/1000 [00:36<01:15,  8.90it/s]
# sampling loop time step:  33%|███▎      | 330/1000 [00:37<01:15,  8.90it/s]
# sampling loop time step:  33%|███▎      | 331/1000 [00:37<01:15,  8.91it/s]
# sampling loop time step:  33%|███▎      | 332/1000 [00:37<01:14,  8.91it/s]
# sampling loop time step:  33%|███▎      | 333/1000 [00:37<01:14,  8.91it/s]
# sampling loop time step:  33%|███▎      | 334/1000 [00:37<01:14,  8.90it/s]
# sampling loop time step:  34%|███▎      | 335/1000 [00:37<01:14,  8.90it/s]
# sampling loop time step:  34%|███▎      | 336/1000 [00:37<01:14,  8.90it/s]
# sampling loop time step:  34%|███▎      | 337/1000 [00:37<01:14,  8.91it/s]
# sampling loop time step:  34%|███▍      | 338/1000 [00:37<01:14,  8.91it/s]
# sampling loop time step:  34%|███▍      | 339/1000 [00:38<01:14,  8.91it/s]
# sampling loop time step:  34%|███▍      | 340/1000 [00:38<01:14,  8.91it/s]
# sampling loop time step:  34%|███▍      | 341/1000 [00:38<01:13,  8.92it/s]
# sampling loop time step:  34%|███▍      | 342/1000 [00:38<01:13,  8.91it/s]
# sampling loop time step:  34%|███▍      | 343/1000 [00:38<01:13,  8.90it/s]
# sampling loop time step:  34%|███▍      | 344/1000 [00:38<01:13,  8.89it/s]
# sampling loop time step:  34%|███▍      | 345/1000 [00:38<01:13,  8.89it/s]
# sampling loop time step:  35%|███▍      | 346/1000 [00:38<01:13,  8.89it/s]
# sampling loop time step:  35%|███▍      | 347/1000 [00:38<01:13,  8.89it/s]
# sampling loop time step:  35%|███▍      | 348/1000 [00:39<01:13,  8.89it/s]
# sampling loop time step:  35%|███▍      | 349/1000 [00:39<01:13,  8.89it/s]
# sampling loop time step:  35%|███▌      | 350/1000 [00:39<01:13,  8.89it/s]
# sampling loop time step:  35%|███▌      | 351/1000 [00:39<01:12,  8.91it/s]
# sampling loop time step:  35%|███▌      | 352/1000 [00:39<01:12,  8.88it/s]
# sampling loop time step:  35%|███▌      | 353/1000 [00:39<01:12,  8.89it/s]
# sampling loop time step:  35%|███▌      | 354/1000 [00:39<01:12,  8.90it/s]
# sampling loop time step:  36%|███▌      | 355/1000 [00:39<01:12,  8.89it/s]
# sampling loop time step:  36%|███▌      | 356/1000 [00:40<01:12,  8.89it/s]
# sampling loop time step:  36%|███▌      | 357/1000 [00:40<01:12,  8.89it/s]
# sampling loop time step:  36%|███▌      | 358/1000 [00:40<01:12,  8.88it/s]
# sampling loop time step:  36%|███▌      | 359/1000 [00:40<01:12,  8.89it/s]
# sampling loop time step:  36%|███▌      | 360/1000 [00:40<01:11,  8.89it/s]
# sampling loop time step:  36%|███▌      | 361/1000 [00:40<01:12,  8.87it/s]
# sampling loop time step:  36%|███▌      | 362/1000 [00:40<01:11,  8.87it/s]
# sampling loop time step:  36%|███▋      | 363/1000 [00:40<01:11,  8.89it/s]
# sampling loop time step:  36%|███▋      | 364/1000 [00:40<01:11,  8.89it/s]
# sampling loop time step:  36%|███▋      | 365/1000 [00:41<01:11,  8.89it/s]
# sampling loop time step:  37%|███▋      | 366/1000 [00:41<01:11,  8.89it/s]
# sampling loop time step:  37%|███▋      | 367/1000 [00:41<01:11,  8.87it/s]
# sampling loop time step:  37%|███▋      | 368/1000 [00:41<01:11,  8.88it/s]
# sampling loop time step:  37%|███▋      | 369/1000 [00:41<01:11,  8.88it/s]
# sampling loop time step:  37%|███▋      | 370/1000 [00:41<01:11,  8.86it/s]
# sampling loop time step:  37%|███▋      | 371/1000 [00:41<01:10,  8.88it/s]
# sampling loop time step:  37%|███▋      | 372/1000 [00:41<01:10,  8.89it/s]
# sampling loop time step:  37%|███▋      | 373/1000 [00:41<01:10,  8.88it/s]
# sampling loop time step:  37%|███▋      | 374/1000 [00:42<01:10,  8.89it/s]
# sampling loop time step:  38%|███▊      | 375/1000 [00:42<01:10,  8.89it/s]
# sampling loop time step:  38%|███▊      | 376/1000 [00:42<01:10,  8.86it/s]
# sampling loop time step:  38%|███▊      | 377/1000 [00:42<01:10,  8.88it/s]
# sampling loop time step:  38%|███▊      | 378/1000 [00:42<01:10,  8.88it/s]
# sampling loop time step:  38%|███▊      | 379/1000 [00:42<01:10,  8.87it/s]
# sampling loop time step:  38%|███▊      | 380/1000 [00:42<01:09,  8.88it/s]
# sampling loop time step:  38%|███▊      | 381/1000 [00:42<01:09,  8.90it/s]
# sampling loop time step:  38%|███▊      | 382/1000 [00:42<01:09,  8.89it/s]
# sampling loop time step:  38%|███▊      | 383/1000 [00:43<01:09,  8.89it/s]
# sampling loop time step:  38%|███▊      | 384/1000 [00:43<01:09,  8.89it/s]
# sampling loop time step:  38%|███▊      | 385/1000 [00:43<01:09,  8.87it/s]
# sampling loop time step:  39%|███▊      | 386/1000 [00:43<01:09,  8.87it/s]
# sampling loop time step:  39%|███▊      | 387/1000 [00:43<01:09,  8.88it/s]
# sampling loop time step:  39%|███▉      | 388/1000 [00:43<01:08,  8.87it/s]
# sampling loop time step:  39%|███▉      | 389/1000 [00:43<01:08,  8.88it/s]
# sampling loop time step:  39%|███▉      | 390/1000 [00:43<01:08,  8.88it/s]
# sampling loop time step:  39%|███▉      | 391/1000 [00:43<01:08,  8.88it/s]
# sampling loop time step:  39%|███▉      | 392/1000 [00:44<01:08,  8.88it/s]
# sampling loop time step:  39%|███▉      | 393/1000 [00:44<01:08,  8.88it/s]
# sampling loop time step:  39%|███▉      | 394/1000 [00:44<01:08,  8.87it/s]
# sampling loop time step:  40%|███▉      | 395/1000 [00:44<01:08,  8.88it/s]
# sampling loop time step:  40%|███▉      | 396/1000 [00:44<01:07,  8.89it/s]
# sampling loop time step:  40%|███▉      | 397/1000 [00:44<01:07,  8.88it/s]
# sampling loop time step:  40%|███▉      | 398/1000 [00:44<01:07,  8.88it/s]
# sampling loop time step:  40%|███▉      | 399/1000 [00:44<01:07,  8.89it/s]
# sampling loop time step:  40%|████      | 400/1000 [00:44<01:07,  8.87it/s]
# sampling loop time step:  40%|████      | 401/1000 [00:45<01:07,  8.88it/s]
# sampling loop time step:  40%|████      | 402/1000 [00:45<01:07,  8.88it/s]
# sampling loop time step:  40%|████      | 403/1000 [00:45<01:07,  8.88it/s]
# sampling loop time step:  40%|████      | 404/1000 [00:45<01:07,  8.89it/s]
# sampling loop time step:  40%|████      | 405/1000 [00:45<01:06,  8.89it/s]
# sampling loop time step:  41%|████      | 406/1000 [00:45<01:07,  8.86it/s]
# sampling loop time step:  41%|████      | 407/1000 [00:45<01:06,  8.87it/s]
# sampling loop time step:  41%|████      | 408/1000 [00:45<01:06,  8.88it/s]
# sampling loop time step:  41%|████      | 409/1000 [00:45<01:06,  8.88it/s]
# sampling loop time step:  41%|████      | 410/1000 [00:46<01:06,  8.89it/s]
# sampling loop time step:  41%|████      | 411/1000 [00:46<01:06,  8.89it/s]
# sampling loop time step:  41%|████      | 412/1000 [00:46<01:06,  8.89it/s]
# sampling loop time step:  53%|█████▎    | 527/1000 [00:59<00:52,  8.96it/s]
# sampling loop time step:  53%|█████▎    | 528/1000 [00:59<00:52,  8.96it/s]
# sampling loop time step:  53%|█████▎    | 529/1000 [00:59<00:52,  8.94it/s]
# sampling loop time step:  53%|█████▎    | 530/1000 [00:59<00:52,  8.92it/s]
# sampling loop time step:  53%|█████▎    | 531/1000 [00:59<00:52,  8.90it/s]
# sampling loop time step:  53%|█████▎    | 532/1000 [00:59<00:52,  8.91it/s]
# sampling loop time step:  53%|█████▎    | 533/1000 [00:59<00:52,  8.90it/s]
# sampling loop time step:  53%|█████▎    | 534/1000 [01:00<00:52,  8.92it/s]
# sampling loop time step:  54%|█████▎    | 535/1000 [01:00<00:52,  8.92it/s]
# sampling loop time step:  54%|█████▎    | 536/1000 [01:00<00:52,  8.92it/s]
# sampling loop time step:  54%|█████▎    | 537/1000 [01:00<00:51,  8.91it/s]
# sampling loop time step:  54%|█████▍    | 538/1000 [01:00<00:51,  8.90it/s]
# sampling loop time step:  54%|█████▍    | 539/1000 [01:00<00:51,  8.90it/s]
# sampling loop time step:  54%|█████▍    | 540/1000 [01:00<00:51,  8.90it/s]
# sampling loop time step:  54%|█████▍    | 541/1000 [01:00<00:51,  8.90it/s]
# sampling loop time step:  54%|█████▍    | 542/1000 [01:00<00:51,  8.89it/s]
# sampling loop time step:  54%|█████▍    | 543/1000 [01:01<00:51,  8.87it/s]
# sampling loop time step:  54%|█████▍    | 544/1000 [01:01<00:51,  8.89it/s]
# sampling loop time step:  55%|█████▍    | 545/1000 [01:01<00:51,  8.88it/s]
# sampling loop time step:  55%|█████▍    | 546/1000 [01:01<00:51,  8.87it/s]
# sampling loop time step:  55%|█████▍    | 547/1000 [01:01<00:51,  8.88it/s]
# sampling loop time step:  55%|█████▍    | 548/1000 [01:01<00:50,  8.88it/s]
# sampling loop time step:  55%|█████▍    | 549/1000 [01:01<00:50,  8.86it/s]
# sampling loop time step:  55%|█████▌    | 550/1000 [01:01<00:50,  8.88it/s]
# sampling loop time step:  55%|█████▌    | 551/1000 [01:01<00:50,  8.89it/s]
# sampling loop time step:  55%|█████▌    | 552/1000 [01:02<00:50,  8.87it/s]
# sampling loop time step:  55%|█████▌    | 553/1000 [01:02<00:50,  8.88it/s]
# sampling loop time step:  55%|█████▌    | 554/1000 [01:02<00:50,  8.88it/s]
# sampling loop time step:  56%|█████▌    | 555/1000 [01:02<00:50,  8.87it/s]
# sampling loop time step:  56%|█████▌    | 556/1000 [01:02<00:49,  8.88it/s]
# sampling loop time step:  56%|█████▌    | 557/1000 [01:02<00:49,  8.90it/s]
# sampling loop time step:  56%|█████▌    | 558/1000 [01:02<00:49,  8.88it/s]
# sampling loop time step:  56%|█████▌    | 559/1000 [01:02<00:49,  8.90it/s]
# sampling loop time step:  56%|█████▌    | 560/1000 [01:02<00:49,  8.88it/s]
# sampling loop time step:  56%|█████▌    | 561/1000 [01:03<00:49,  8.88it/s]
# sampling loop time step:  56%|█████▌    | 562/1000 [01:03<00:49,  8.89it/s]
# sampling loop time step:  56%|█████▋    | 563/1000 [01:03<00:49,  8.88it/s]
# sampling loop time step:  56%|█████▋    | 564/1000 [01:03<00:49,  8.87it/s]
# sampling loop time step:  56%|█████▋    | 565/1000 [01:03<00:49,  8.87it/s]
# sampling loop time step:  57%|█████▋    | 566/1000 [01:03<00:48,  8.88it/s]
# sampling loop time step:  57%|█████▋    | 567/1000 [01:03<00:48,  8.88it/s]
# sampling loop time step:  57%|█████▋    | 568/1000 [01:03<00:48,  8.88it/s]
# sampling loop time step:  57%|█████▋    | 569/1000 [01:03<00:48,  8.90it/s]
# sampling loop time step:  57%|█████▋    | 570/1000 [01:04<00:48,  8.89it/s]
# sampling loop time step:  57%|█████▋    | 571/1000 [01:04<00:48,  8.89it/s]
# sampling loop time step:  57%|█████▋    | 572/1000 [01:04<00:48,  8.88it/s]
# sampling loop time step:  57%|█████▋    | 573/1000 [01:04<00:48,  8.87it/s]
# sampling loop time step:  57%|█████▋    | 574/1000 [01:04<00:48,  8.87it/s]
# sampling loop time step:  57%|█████▊    | 575/1000 [01:04<00:47,  8.87it/s]
# sampling loop time step:  58%|█████▊    | 576/1000 [01:04<00:47,  8.86it/s]
# sampling loop time step:  58%|█████▊    | 577/1000 [01:04<00:47,  8.87it/s]
# sampling loop time step:  58%|█████▊    | 578/1000 [01:04<00:47,  8.88it/s]
# sampling loop time step:  58%|█████▊    | 579/1000 [01:05<00:47,  8.86it/s]
# sampling loop time step:  58%|█████▊    | 580/1000 [01:05<00:47,  8.87it/s]
# sampling loop time step:  58%|█████▊    | 581/1000 [01:05<00:47,  8.87it/s]
# sampling loop time step:  58%|█████▊    | 582/1000 [01:05<00:47,  8.86it/s]
# sampling loop time step:  58%|█████▊    | 583/1000 [01:05<00:46,  8.89it/s]
# sampling loop time step:  58%|█████▊    | 584/1000 [01:05<00:46,  8.89it/s]
# sampling loop time step:  58%|█████▊    | 585/1000 [01:05<00:46,  8.89it/s]
# sampling loop time step:  59%|█████▊    | 586/1000 [01:05<00:46,  8.89it/s]
# sampling loop time step:  59%|█████▊    | 587/1000 [01:06<00:46,  8.89it/s]
# sampling loop time step:  59%|█████▉    | 588/1000 [01:06<00:46,  8.88it/s]
# sampling loop time step:  59%|█████▉    | 589/1000 [01:06<00:46,  8.88it/s]
# sampling loop time step:  59%|█████▉    | 590/1000 [01:06<00:46,  8.88it/s]
# sampling loop time step:  59%|█████▉    | 591/1000 [01:06<00:46,  8.89it/s]
# sampling loop time step:  59%|█████▉    | 592/1000 [01:06<00:45,  8.89it/s]
# sampling loop time step:  59%|█████▉    | 593/1000 [01:06<00:45,  8.90it/s]
# sampling loop time step:  59%|█████▉    | 594/1000 [01:06<00:45,  8.88it/s]
# sampling loop time step:  60%|█████▉    | 595/1000 [01:06<00:45,  8.88it/s]
# sampling loop time step:  60%|█████▉    | 596/1000 [01:07<00:45,  8.89it/s]
# sampling loop time step:  60%|█████▉    | 597/1000 [01:07<00:45,  8.88it/s]
# sampling loop time step:  52%|█████▏    | 518/1000 [00:25<00:23, 20.70it/s]
# sampling loop time step:  52%|█████▏    | 521/1000 [00:25<00:23, 20.71it/s]
# sampling loop time step:  52%|█████▏    | 524/1000 [00:25<00:23, 20.56it/s]
# sampling loop time step:  53%|█████▎    | 527/1000 [00:25<00:23, 20.42it/s]
# sampling loop time step:  53%|█████▎    | 530/1000 [00:25<00:22, 20.53it/s]
# sampling loop time step:  53%|█████▎    | 533/1000 [00:26<00:22, 20.60it/s]
# sampling loop time step:  54%|█████▎    | 536/1000 [00:26<00:22, 20.61it/s]
# sampling loop time step:  54%|█████▍    | 539/1000 [00:26<00:22, 20.74it/s]
# sampling loop time step:  54%|█████▍    | 542/1000 [00:26<00:21, 20.84it/s]
# sampling loop time step:  55%|█████▍    | 545/1000 [00:26<00:22, 20.59it/s]
# sampling loop time step:  55%|█████▍    | 548/1000 [00:26<00:22, 20.51it/s]
# sampling loop time step:  55%|█████▌    | 551/1000 [00:26<00:21, 20.56it/s]
# sampling loop time step:  55%|█████▌    | 554/1000 [00:27<00:21, 20.59it/s]
# sampling loop time step:  56%|█████▌    | 557/1000 [00:27<00:21, 20.54it/s]
# sampling loop time step:  56%|█████▌    | 560/1000 [00:27<00:21, 20.74it/s]
# sampling loop time step:  56%|█████▋    | 563/1000 [00:27<00:21, 20.67it/s]
# sampling loop time step:  57%|█████▋    | 566/1000 [00:27<00:20, 20.75it/s]
# sampling loop time step:  57%|█████▋    | 569/1000 [00:27<00:21, 20.48it/s]
# sampling loop time step:  57%|█████▋    | 572/1000 [00:28<00:20, 20.46it/s]
# sampling loop time step:  57%|█████▊    | 575/1000 [00:28<00:20, 20.56it/s]
# sampling loop time step:  58%|█████▊    | 578/1000 [00:28<00:20, 20.62it/s]
# sampling loop time step:  58%|█████▊    | 581/1000 [00:28<00:20, 20.70it/s]
# sampling loop time step:  58%|█████▊    | 584/1000 [00:28<00:20, 20.78it/s]
# sampling loop time step:  59%|█████▊    | 587/1000 [00:28<00:20, 20.65it/s]
# sampling loop time step:  59%|█████▉    | 590/1000 [00:28<00:19, 20.57it/s]
# sampling loop time step:  59%|█████▉    | 593/1000 [00:29<00:19, 20.54it/s]
# sampling loop time step:  60%|█████▉    | 596/1000 [00:29<00:19, 20.68it/s]
# sampling loop time step:  60%|█████▉    | 599/1000 [00:29<00:19, 20.81it/s]
# sampling loop time step:  60%|██████    | 602/1000 [00:29<00:19, 20.91it/s]
# sampling loop time step:  60%|██████    | 605/1000 [00:29<00:18, 20.87it/s]
# sampling loop time step:  61%|██████    | 608/1000 [00:29<00:18, 20.76it/s]
# sampling loop time step:  61%|██████    | 611/1000 [00:29<00:18, 20.62it/s]
# sampling loop time step:  61%|██████▏   | 614/1000 [00:30<00:18, 20.48it/s]
# sampling loop time step:  62%|██████▏   | 617/1000 [00:30<00:18, 20.57it/s]
# sampling loop time step:  62%|██████▏   | 620/1000 [00:30<00:18, 20.62it/s]
# sampling loop time step:  62%|██████▏   | 623/1000 [00:30<00:18, 20.67it/s]
# sampling loop time step:  63%|██████▎   | 626/1000 [00:30<00:18, 20.58it/s]
# sampling loop time step:  63%|██████▎   | 629/1000 [00:30<00:18, 20.57it/s]
# sampling loop time step:  63%|██████▎   | 632/1000 [00:30<00:18, 20.19it/s]
# sampling loop time step:  64%|██████▎   | 635/1000 [00:31<00:18, 19.53it/s]
# sampling loop time step:  64%|██████▎   | 637/1000 [00:31<00:18, 19.48it/s]
# sampling loop time step:  64%|██████▍   | 639/1000 [00:31<00:18, 19.52it/s]
# sampling loop time step:  64%|██████▍   | 642/1000 [00:31<00:17, 19.93it/s]
# sampling loop time step:  64%|██████▍   | 644/1000 [00:31<00:17, 19.91it/s]
# sampling loop time step:  65%|██████▍   | 647/1000 [00:31<00:17, 20.17it/s]
# sampling loop time step:  65%|██████▌   | 650/1000 [00:31<00:17, 20.12it/s]
# sampling loop time step:  65%|██████▌   | 653/1000 [00:31<00:17, 19.94it/s]
# sampling loop time step:  66%|██████▌   | 655/1000 [00:32<00:17, 19.86it/s]
# sampling loop time step:  66%|██████▌   | 657/1000 [00:32<00:17, 19.77it/s]
# sampling loop time step:  66%|██████▌   | 660/1000 [00:32<00:16, 20.22it/s]
# sampling loop time step:  66%|██████▋   | 663/1000 [00:32<00:16, 20.46it/s]
# sampling loop time step:  67%|██████▋   | 666/1000 [00:32<00:16, 20.39it/s]
# sampling loop time step:  67%|██████▋   | 669/1000 [00:32<00:17, 19.38it/s]
# sampling loop time step:  67%|██████▋   | 671/1000 [00:32<00:17, 19.18it/s]
# sampling loop time step:  67%|██████▋   | 673/1000 [00:33<00:17, 19.16it/s]
# sampling loop time step:  68%|██████▊   | 675/1000 [00:33<00:16, 19.15it/s]
# sampling loop time step:  68%|██████▊   | 677/1000 [00:33<00:16, 19.20it/s]
# sampling loop time step:  68%|██████▊   | 679/1000 [00:33<00:16, 19.13it/s]
# sampling loop time step:  68%|██████▊   | 681/1000 [00:33<00:16, 19.20it/s]
# sampling loop time step:  68%|██████▊   | 683/1000 [00:33<00:16, 19.36it/s]
# sampling loop time step:  68%|██████▊   | 685/1000 [00:33<00:16, 19.20it/s]
# sampling loop time step:  69%|██████▊   | 687/1000 [00:33<00:16, 19.30it/s]
# sampling loop time step:  69%|██████▉   | 689/1000 [00:33<00:16, 18.98it/s]
# sampling loop time step:  69%|██████▉   | 691/1000 [00:33<00:16, 18.76it/s]
# sampling loop time step:  69%|██████▉   | 693/1000 [00:34<00:16, 18.95it/s]
# sampling loop time step:  70%|██████▉   | 695/1000 [00:34<00:15, 19.20it/s]
# sampling loop time step:  70%|██████▉   | 698/1000 [00:34<00:15, 19.79it/s]
# sampling loop time step:  70%|███████   | 700/1000 [00:34<00:15, 19.84it/s]
# sampling loop time step:  70%|███████   | 702/1000 [00:34<00:14, 19.87it/s]
# sampling loop time step:  70%|███████   | 705/1000 [00:34<00:14, 20.22it/s]
# sampling loop time step:  71%|███████   | 708/1000 [00:34<00:14, 20.22it/s]
# sampling loop time step:  71%|███████   | 711/1000 [00:34<00:14, 20.30it/s]
# sampling loop time step:  71%|███████▏  | 714/1000 [00:35<00:13, 20.46it/s]
# sampling loop time step:  72%|███████▏  | 717/1000 [00:35<00:13, 20.62it/s]
# sampling loop time step:  72%|███████▏  | 720/1000 [00:35<00:13, 20.59it/s]
# sampling loop time step:  72%|███████▏  | 723/1000 [00:35<00:13, 20.72it/s]
# sampling loop time step:  73%|███████▎  | 726/1000 [00:35<00:13, 20.56it/s]
# sampling loop time step:  73%|███████▎  | 729/1000 [00:35<00:13, 20.62it/s]
# sampling loop time step:  73%|███████▎  | 732/1000 [00:35<00:12, 20.72it/s]
# sampling loop time step:  74%|███████▎  | 735/1000 [00:36<00:12, 20.57it/s]
# sampling loop time step:  74%|███████▍  | 738/1000 [00:36<00:13, 20.15it/s]
# sampling loop time step:  74%|███████▍  | 741/1000 [00:36<00:12, 20.33it/s]
# sampling loop time step:  74%|███████▍  | 744/1000 [00:36<00:12, 20.61it/s]
# sampling loop time step:  75%|███████▍  | 747/1000 [00:36<00:12, 20.71it/s]
# sampling loop time step:  75%|███████▌  | 750/1000 [00:36<00:12, 20.71it/s]
# sampling loop time step:  75%|███████▌  | 753/1000 [00:36<00:12, 20.42it/s]
# sampling loop time step:  76%|███████▌  | 756/1000 [00:37<00:11, 20.55it/s]
# sampling loop time step:  76%|███████▌  | 759/1000 [00:37<00:11, 20.49it/s]
# sampling loop time step:  76%|███████▌  | 762/1000 [00:37<00:11, 20.40it/s]
# sampling loop time step:  76%|███████▋  | 765/1000 [00:37<00:11, 20.53it/s]
# sampling loop time step:  77%|███████▋  | 768/1000 [00:37<00:11, 20.61it/s]
# sampling loop time step:  77%|███████▋  | 771/1000 [00:37<00:11, 20.48it/s]
# sampling loop time step:  77%|███████▋  | 774/1000 [00:38<00:11, 20.36it/s]
# sampling loop time step:  78%|███████▊  | 777/1000 [00:38<00:10, 20.35it/s]
# sampling loop time step:  78%|███████▊  | 780/1000 [00:38<00:10, 20.54it/s]
# sampling loop time step:  78%|███████▊  | 783/1000 [00:38<00:10, 20.72it/s]
# sampling loop time step:  79%|███████▊  | 786/1000 [00:38<00:10, 20.95it/s]
# sampling loop time step:  79%|███████▉  | 789/1000 [00:38<00:10, 20.89it/s]
# sampling loop time step:  79%|███████▉  | 792/1000 [00:38<00:09, 21.08it/s]
# sampling loop time step:  80%|███████▉  | 795/1000 [00:39<00:09, 20.79it/s]
# sampling loop time step:  80%|███████▉  | 798/1000 [00:39<00:09, 20.76it/s]
# sampling loop time step:  80%|████████  | 801/1000 [00:39<00:09, 20.82it/s]
# sampling loop time step:  80%|████████  | 804/1000 [00:39<00:09, 20.88it/s]
# sampling loop time step:  81%|████████  | 807/1000 [00:39<00:09, 20.74it/s]
# sampling loop time step:  81%|████████  | 810/1000 [00:39<00:09, 20.70it/s]
# sampling loop time step:  81%|████████▏ | 813/1000 [00:39<00:09, 20.74it/s]
# sampling loop time step:  82%|████████▏ | 816/1000 [00:40<00:08, 20.46it/s]
# sampling loop time step:  82%|████████▏ | 819/1000 [00:40<00:08, 20.47it/s]
# sampling loop time step:  82%|████████▏ | 822/1000 [00:40<00:08, 20.50it/s]
# sampling loop time step:  82%|████████▎ | 825/1000 [00:40<00:08, 20.41it/s]
# sampling loop time step:  83%|████████▎ | 828/1000 [00:40<00:08, 20.44it/s]
# sampling loop time step:  83%|████████▎ | 831/1000 [00:40<00:08, 20.44it/s]
# sampling loop time step:  83%|████████▎ | 834/1000 [00:40<00:08, 20.61it/s]
# sampling loop time step:  84%|████████▎ | 837/1000 [00:41<00:07, 20.64it/s]
# sampling loop time step:  84%|████████▍ | 840/1000 [00:41<00:07, 20.56it/s]
# sampling loop time step:  84%|████████▍ | 843/1000 [00:41<00:07, 20.39it/s]
# sampling loop time step:  85%|████████▍ | 846/1000 [00:41<00:07, 20.26it/s]
# sampling loop time step:  85%|████████▍ | 849/1000 [00:41<00:07, 20.49it/s]
# sampling loop time step:  85%|████████▌ | 852/1000 [00:41<00:07, 20.48it/s]
# sampling loop time step:  86%|████████▌ | 855/1000 [00:41<00:07, 20.61it/s]
# sampling loop time step:  86%|████████▌ | 858/1000 [00:42<00:06, 20.46it/s]
# sampling loop time step:  86%|████████▌ | 861/1000 [00:42<00:06, 20.38it/s]
# sampling loop time step:  86%|████████▋ | 864/1000 [00:42<00:06, 20.43it/s]
# sampling loop time step:  87%|████████▋ | 867/1000 [00:42<00:06, 20.63it/s]
# sampling loop time step:  87%|████████▋ | 870/1000 [00:42<00:06, 20.35it/s]
# sampling loop time step:  87%|████████▋ | 873/1000 [00:42<00:06, 20.40it/s]
# sampling loop time step:  88%|████████▊ | 876/1000 [00:42<00:06, 20.55it/s]
# sampling loop time step:  88%|████████▊ | 879/1000 [00:43<00:05, 20.38it/s]
# sampling loop time step:  88%|████████▊ | 882/1000 [00:43<00:05, 20.39it/s]
# sampling loop time step:  88%|████████▊ | 885/1000 [00:43<00:05, 20.57it/s]
# sampling loop time step:  89%|████████▉ | 888/1000 [00:43<00:05, 20.65it/s]
# sampling loop time step:  89%|████████▉ | 891/1000 [00:43<00:05, 20.56it/s]
# sampling loop time step:  89%|████████▉ | 894/1000 [00:43<00:05, 20.46it/s]
# sampling loop time step:  90%|████████▉ | 897/1000 [00:43<00:04, 20.67it/s]
# sampling loop time step:  90%|█████████ | 900/1000 [00:44<00:04, 20.63it/s]
# sampling loop time step:  90%|█████████ | 903/1000 [00:44<00:04, 20.81it/s]
# sampling loop time step:  91%|█████████ | 906/1000 [00:44<00:04, 20.40it/s]
# sampling loop time step:  91%|█████████ | 909/1000 [00:44<00:04, 20.39it/s]
# sampling loop time step:  91%|█████████ | 912/1000 [00:44<00:04, 20.50it/s]
# sampling loop time step:  92%|█████████▏| 915/1000 [00:44<00:04, 20.58it/s]
# sampling loop time step:  92%|█████████▏| 918/1000 [00:45<00:04, 20.48it/s]
# sampling loop time step:  92%|█████████▏| 921/1000 [00:45<00:03, 20.50it/s]
# sampling loop time step:  92%|█████████▏| 924/1000 [00:45<00:03, 20.58it/s]
# sampling loop time step:  93%|█████████▎| 927/1000 [00:45<00:03, 20.59it/s]
# sampling loop time step:  93%|█████████▎| 930/1000 [00:45<00:03, 20.68it/s]
# sampling loop time step:  93%|█████████▎| 933/1000 [00:45<00:03, 20.77it/s]
# sampling loop time step:  94%|█████████▎| 936/1000 [00:45<00:03, 20.91it/s]
# sampling loop time step:  94%|█████████▍| 939/1000 [00:46<00:02, 20.72it/s]
# sampling loop time step:  94%|█████████▍| 942/1000 [00:46<00:02, 20.80it/s]
# sampling loop time step:  94%|█████████▍| 945/1000 [00:46<00:02, 20.90it/s]
# sampling loop time step:  95%|█████████▍| 948/1000 [00:46<00:02, 20.99it/s]
# sampling loop time step:  95%|█████████▌| 951/1000 [00:46<00:02, 20.92it/s]
# sampling loop time step:  95%|█████████▌| 954/1000 [00:46<00:02, 20.81it/s]
# sampling loop time step:  96%|█████████▌| 957/1000 [00:46<00:02, 20.79it/s]
# sampling loop time step:  96%|█████████▌| 960/1000 [00:47<00:01, 20.57it/s]
# sampling loop time step:  96%|█████████▋| 963/1000 [00:47<00:01, 20.34it/s]
# sampling loop time step:  97%|█████████▋| 966/1000 [00:47<00:01, 20.60it/s]
# sampling loop time step:  97%|█████████▋| 969/1000 [00:47<00:01, 20.55it/s]
# sampling loop time step:  97%|█████████▋| 972/1000 [00:47<00:01, 20.58it/s]
# sampling loop time step:  98%|█████████▊| 975/1000 [00:47<00:01, 20.37it/s]
# sampling loop time step:  98%|█████████▊| 978/1000 [00:47<00:01, 20.37it/s]
# sampling loop time step:  98%|█████████▊| 981/1000 [00:48<00:00, 20.44it/s]
# sampling loop time step:  98%|█████████▊| 984/1000 [00:48<00:00, 20.30it/s]
# sampling loop time step:  99%|█████████▊| 987/1000 [00:48<00:00, 20.51it/s]
# sampling loop time step:  99%|█████████▉| 990/1000 [00:48<00:00, 20.65it/s]
# sampling loop time step:  99%|█████████▉| 993/1000 [00:48<00:00, 20.34it/s]
# sampling loop time step: 100%|█████████▉| 996/1000 [00:48<00:00, 20.49it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:48<00:00, 20.41it/s]
# 2it [02:41, 80.88s/it]
# /usr/local/lib/python3.7/dist-packages/IPython/core/formatters.py:364: FormatterWarning: image/png formatter returned invalid type <class 'torch.Tensor'> (expected (<class 'bytes'>, <class 'str'>)) for object: <IPython.core.display.Image object>
#   FormatterWarning

# %%
# !imagen --model ./path/to/model/checkpoint.pt "a squirrel raiding the birdfeeder"
# image is saved to ./a_squirrel_raiding_the_birdfeeder.png
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/imagen", line 8, in <module>
#     sys.exit(imagen())
#   File "/usr/local/lib/python3.7/dist-packages/click/core.py", line 829, in __call__
#     return self.main(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/click/core.py", line 782, in main
#     rv = self.invoke(ctx)
#   File "/usr/local/lib/python3.7/dist-packages/click/core.py", line 1066, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/usr/local/lib/python3.7/dist-packages/click/core.py", line 610, in invoke
#     return callback(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/imagen_pytorch/cli.py", line 31, in imagen
#     assert model_path.exists(), f'model not found at {full_model_path}'
# AssertionError: model not found at /content/parti-pytorch/path/to/model/checkpoint.pt

# %%
# !git clone https://github.com/lucidrains/parti-pytorch.git
# Out:
# Cloning into 'parti-pytorch'...
# remote: Enumerating objects: 215, done.
# remote: Counting objects: 100% (58/58), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 215 (delta 36), reused 32 (delta 17), pack-reused 157
# Receiving objects: 100% (215/215), 319.44 KiB | 7.99 MiB/s, done.
# Resolving deltas: 100% (132/132), done.
